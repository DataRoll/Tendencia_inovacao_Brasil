# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#inovacao, predicao, tendencia, indicador, previsao, prognostico, innovation, forecast, prediction, trend, indicator, prognosis
inovacao=pd.read_csv('Dados palavra chave/inovação_scopus.csv', sep=';')
predicao=pd.read_csv('Dados palavra chave/predição_scopus.csv', sep=';')
tendencia=pd.read_csv('Dados palavra chave/tendência_scopus.csv', sep=';')
indicador=pd.read_csv('Dados palavra chave/indicador_scopus.csv', sep=';')
previsao=pd.read_csv('Dados palavra chave/previsão_scopus.csv', sep=';')
prognostico=pd.read_csv('Dados palavra chave/prognostico_scopus.csv', sep=';')
innovation=pd.read_csv('Dados palavra chave/innovation_scopus.csv', sep=';')
forecast=pd.read_csv('Dados palavra chave/forecast_scopus.csv', sep=';')
prediction=pd.read_csv('Dados palavra chave/prediction_scopus.csv', sep=';')
trend=pd.read_csv('Dados palavra chave/trend_scopus.csv', sep=';')
indicator=pd.read_csv('Dados palavra chave/indicator_scopus.csv', sep=';')
prognosis=pd.read_csv('Dados palavra chave/prognosis_scopus.csv', sep=';')

# %%
plt.figure(figsize=(16,8))

plt.title('Numero de publicações por ano na revista Scopus', fontdict={'fontweight':'bold', 'fontsize': 15})

plt.plot(predicao.years, predicao.publications, 'g.-', label='predicao')
plt.plot(tendencia.years, tendencia.publications, 'g.-', label='tendencia')
plt.plot(inovacao.years, inovacao.publications, 'g.-', label='inovacao')
plt.plot(indicador.years, indicador.publications, 'g.-', label='indicador')
plt.plot(previsao.years, previsao.publications, 'g.-', label='previsao')
plt.plot(prognostico.years, prognostico.publications, 'g.-', label='prognostico')
plt.plot(innovation.years, innovation.publications, 'r.-', label='innovation')
plt.plot(forecast.years, forecast.publications, 'r.-', label='forecast')
plt.plot(prediction.years, prediction.publications, 'r.-', label='prediction')
plt.plot(trend.years, trend.publications, 'r.-', label='trend')
plt.plot(indicator.years, indicator.publications, 'r.-', label='indicator')
plt.plot(prognosis.years, prognosis.publications, 'r.-', label='prognosis')


plt.xlabel('Year',fontdict={'fontweight':'bold', 'fontsize': 15})
plt.ylabel('publications', fontdict={'fontweight':'bold', 'fontsize': 15})
plt.xscale("linear")
plt.yscale("linear")

plt.legend()
plt.savefig('grafico1.svg')
plt.show()

# %% [markdown]
# - Plotou o grafico com as palavras em inglês de vermelho e as em protuguês(Br) de verde
# - Conclui-se que as palavras em português são irrelevante, até porque a scopus é um site internacional

# %% [markdown]
# ## As palavras chave em português tiveram pouca relevância, então, vamos dar continuidade apenas com as palavras em inglês

# %%
plt.figure(figsize=(16,8))

plt.title('Publicações brasileiras com palavras chave na Revista Scopus', fontdict={'fontweight':'bold', 'fontsize': 15})
plt.plot(trend.years, trend.publications, 'g.-', label='trend')
plt.plot(prediction.years, prediction.publications, 'k.-', label='prediction')
plt.plot(indicator.years, indicator.publications, 'm.-', label='indicator')
plt.plot(innovation.years, innovation.publications, 'b.-', label='innovation')
plt.plot(prognosis.years, prognosis.publications, 'r.-', label='prognosis')
plt.plot(forecast.years, forecast.publications, 'c.-', label='forecast')

plt.xscale("linear")
plt.yscale("linear")
plt.legend(loc='best') #colocando a legenda no melhor lugar
plt.xlabel('Year',fontdict={'fontweight':'bold', 'fontsize': 15})
plt.ylabel('publications', fontdict={'fontweight':'bold', 'fontsize': 15})

plt.legend()
plt.savefig('grafico2.svg')
plt.show()
